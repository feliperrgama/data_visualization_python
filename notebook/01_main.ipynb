# %%
# defining a color palette

BLUE1, BLUE2, BLUE3, BLUE4, BLUE5 = '#03045e', '#0077b6', "#00b4d8", '#90e0ef', '#CDDBF3'
GREY1, GREY2, GREY3, GREY4, GREY5 = '#212529', '#495057', '#adb5bd', '#dee2e6', '#f8f9fa'
RED1, ORANGE1, YELLOW1, GREEN1, GREEN2 = '#e76f51', '#f4a261',	'#e9c46a', '#4c956c', '#2a9d8f'

# %%
import pandas as pd

# %%
# importing the sells relatory
sells = pd.read_csv("../data/raw/relatorio_vendas.csv")

sells["data_pedido"] = pd.to_datetime(sells["data_envio"], format="%Y-%m-%d")
sells["data_envio"] = pd.to_datetime(sells["data_envio"], format="%Y-%m-%d")

sells
# Out:
#      data_pedido data_envio      modo_envio       nome_cliente  \
# 0     2018-11-12 2018-11-12       Econômica    Thiago Silveira
# 1     2018-11-12 2018-11-12       Econômica    Thiago Silveira
# 2     2018-06-17 2018-06-17       Econômica      Giovanna Lima
# 3     2017-10-19 2017-10-19  Entrega padrão  Ana Júlia da Cruz
# 4     2017-10-19 2017-10-19  Entrega padrão  Ana Júlia da Cruz
# ...          ...        ...             ...                ...
# 8935  2018-10-04 2018-10-04  Entrega padrão     Enrique Santos
# 8936  2019-11-22 2019-11-22  Entrega padrão    Heitor Silveira
# 8937  2019-11-22 2019-11-22  Entrega padrão    Heitor Silveira
# 8938  2016-01-24 2016-01-24       Econômica      Isabel Araújo
# 8939  2019-05-10 2019-05-10       Econômica   Esther Rodrigues
#
#      segmento_cliente          cidade               estado    regiao  \
# 0                 B2C  Ribeirão Preto            São Paulo   Sudeste
# ...

# %%
sells.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data_pedido          8940 non-null   datetime64[us]
#  1   data_envio           8940 non-null   datetime64[us]
#  2   modo_envio           8940 non-null   str
#  3   nome_cliente         8940 non-null   str
#  4   segmento_cliente     8940 non-null   str
#  5   cidade               8940 non-null   str
#  6   estado               8940 non-null   str
#  7   regiao               8940 non-null   str
#  8   departamento         8940 non-null   str
#  9   tipo_produto         8940 non-null   str
#  10  preco_base           8940 non-null   float64
#  11  preco_unit_sem_desc  8940 non-null   float64
#  12  desconto             8940 non-null   float64
#  13  preco_unit_venda     8940 non-null   float64
#  14  quantidade           8940 non-null   int64
# ...
